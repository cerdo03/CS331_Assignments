# %%
import numpy as np
import pandas as pd
from scipy.stats import multivariate_normal as mvn
import sys
import numpy as np
from scipy.stats import multivariate_normal as mvn
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
faithful_df=pd.read_csv('faithful.csv')
faithful_df
# Out:
#      Unnamed: 0  eruptions  waiting
# 0             1      3.600       79
# 1             2      1.800       54
# 2             3      3.333       74
# 3             4      2.283       62
# 4             5      4.533       85
# ..          ...        ...      ...
# 267         268      4.117       81
# 268         269      2.150       46
# 269         270      4.417       90
# 270         271      1.817       46
# 271         272      4.467       74
#
# [272 rows x 3 columns]

# %%
del faithful_df['Unnamed: 0']
faithful_df
# Out:
#      eruptions  waiting
# 0        3.600       79
# 1        1.800       54
# 2        3.333       74
# 3        2.283       62
# 4        4.533       85
# ..         ...      ...
# 267      4.117       81
# 268      2.150       46
# 269      4.417       90
# 270      1.817       46
# 271      4.467       74
#
# [272 rows x 2 columns]

# %%
def generateZ(mu,cov):
  #generating points
  x, y = np.meshgrid(np.linspace(1,6,1000),np.linspace(30,100,1000))
  xy = np.column_stack([x.flat, y.flat])
  #density values at the generated points
  Z = mvn.pdf(xy, mu, cov).reshape(x.shape)
  return x,y,Z

# %%
def Estep(df,mu,sigma,pi):
    X=df.to_numpy()
    K=sigma.shape[0]
    N=X.shape[0]
    gamma = np.zeros(shape=(N, K))
    for k in range(K):
        gamma[:, k] = mvn.pdf(X, mu[k], sigma[k]) * pi[k]
    gamma = gamma/np.sum(gamma, axis=1, keepdims=True)
    return gamma

# %%
def Mstep(df,gamma):
    X=df.to_numpy()
    N=X.shape[0]
    K=gamma.shape[1]
    pi = np.sum(gamma, axis=0)/np.sum(gamma)
    mu = X[np.random.choice(N, size=K, replace=False), :]
    sigma = np.zeros(shape=(K, X.shape[1], X.shape[1]), dtype=np.float)
    for k in range(K):
        mu[k, :] = np.sum(gamma[:, k].reshape(-1,1) * X, axis=0) / np.sum(gamma[:, k], keepdims=True)
        sigma[k, :, :] = np.sum(gamma[:, k].reshape(-1, 1, 1) * ((X-mu[k, :]).reshape(N, X.shape[1], 1)@(X-mu[k, :]).reshape(N, 1, X.shape[1])), axis=0) /np.sum(gamma[:, k])
    return mu, sigma, pi

# %%
def logLikelihood(df,gamma,sigma,mu,pi):
    X = df.to_numpy()
    K = mu.shape[0]
    llh=0
    for k in range(K):
        llh += np.sum(gamma[:, k] * (np.log(mvn.pdf(X, mean=mu[k], cov=sigma[k])) + np.log(pi[k])))
    return llh

# %%
def EM(df,K,delta=0.0001):
    X=df.to_numpy()
    N, D = X.shape
    mu = X[np.random.choice(N, size=K, replace=False), :]
    pi = np.ones(shape=(K), dtype=np.float)/K
    sigma = np.zeros(shape=(K, D, D), dtype=np.float)
    for d in range(D):
        sigma[:, d, d] = np.var(X[:, d])/10
        
    cur_llh = np.float(1e9)
    prev_llh=0.0
    iter=0
    while(abs(cur_llh-prev_llh)>delta):
        gamma = Estep(df, mu, sigma, pi)
        mu, sigma, pi = Mstep(df, gamma)
        
        prev_llh = cur_llh
        cur_llh = logLikelihood(df, gamma, sigma, mu, pi)

        labels = np.argmax(gamma, axis=1)
        iter=iter+1
        plt.figure()
        c=['blue','red','black']

        plt.scatter(faithful_df['eruptions'], faithful_df['waiting'],c=gamma[:,1],cmap='cool')
        for i in range(0,K):
            x,y,z=generateZ(mu[i],sigma[i])
            plt.contour(x, y, z,colors=c[i])
        plt.show()


    return mu, sigma, pi, gamma, labels

# %%
mu, sigma, pi, gamma, labels=EM(faithful_df,2)

# %%
gamma
# Out:
# array([[9.99999997e-01, 2.59221134e-09],
#        [1.90799945e-09, 9.99999998e-01],
#        [9.99991578e-01, 8.42197395e-06],
#        [1.06686812e-05, 9.99989331e-01],
#        [1.00000000e+00, 1.00128227e-21],
#        [7.33220833e-03, 9.92667792e-01],
#        [1.00000000e+00, 1.38335519e-24],
#        [1.00000000e+00, 2.62663639e-10],
#        [2.22109783e-09, 9.99999998e-01],
#        [1.00000000e+00, 3.19383745e-19],
#        [2.56646152e-09, 9.99999997e-01],
#        [1.00000000e+00, 1.19580786e-13],
#        [1.00000000e+00, 3.77807533e-16],
#        [6.13560308e-11, 1.00000000e+00],
#        [1.00000000e+00, 8.16104951e-24],
#        [3.83863182e-08, 9.99999962e-01],
#        [3.82275712e-08, 9.99999962e-01],
#        [1.00000000e+00, 1.86023994e-25],
#        [1.63690735e-10, 1.00000000e+00],
#        [1.00000000e+00, 5.91606852e-17],
#        [5.28323454e-10, 9.99999999e-01],
#        [6.13560308e-11, 1.00000000e+00],
#        [9.99999870e-01, 1.29931251e-07],
#        [9.84980288e-01, 1.50197120e-02],
#        [1.00000000e+00, 5.23450316e-20],
#        [9.99999999e-01, 5.63128741e-10],
#        [1.44303268e-08, 9.99999986e-01],
#        [1.00000000e+00, 2.36278240e-14],
#        [1.00000000e+00, 6.76522201e-12],
#        [1.00000000e+00, 2.12495491e-19],
#        [1.00000000e+00, 1.17412992e-16],
#        [1.00000000e+00, 1.48901411e-19],
#        [9.99911028e-01, 8.89716788e-05],
#        [1.00000000e+00, 2.20067503e-14],
#        [1.00000000e+00, 4.77936327e-11],
#        [6.86776868e-09, 9.99999993e-01],
#        [2.72072788e-10, 1.00000000e+00],
#        [1.00000000e+00, 2.41005310e-25],
#        [2.16778328e-08, 9.99999978e-01],
#        [1.00000000e+00, 4.03535284e-26],
#        [1.00000000e+00, 1.96792115e-18],
#        [2.24797533e-08, 9.99999978e-01],
#        [1.00000000e+00, 4.75087537e-22],
#        [6.89220419e-09, 9.99999993e-01],
#        [1.00000000e+00, 7.50602314e-20],
#        [9.99999639e-01, 3.61408417e-07],
#        [9.99999998e-01, 2.08658277e-09],
#        [2.64515592e-08, 9.99999974e-01],
#        [1.00000000e+00, 1.10363590e-22],
#        [1.10467497e-07, 9.99999890e-01],
#        [1.00000000e+00, 4.47351343e-24],
#        [1.00000000e+00, 3.96733038e-25],
#        [2.56646152e-09, 9.99999997e-01],
#        [1.00000000e+00, 2.41005310e-25],
#        [1.07659722e-09, 9.99999999e-01],
#        [1.00000000e+00, 1.43802191e-26],
#        [9.99999997e-01, 3.00051712e-09],
#        [4.71284228e-08, 9.99999953e-01],
#        [1.00000000e+00, 5.85347503e-21],
#        [1.00000000e+00, 3.75930867e-18],
#        [1.61902782e-06, 9.99998381e-01],
#        [1.00000000e+00, 4.14818893e-21],
#        [9.43053023e-11, 1.00000000e+00],
#        [1.00000000e+00, 2.22309302e-17],
#        [2.29735763e-09, 9.99999998e-01],
#        [1.00000000e+00, 1.37890146e-21],
#        [5.32425463e-11, 1.00000000e+00],
#        [1.00000000e+00, 3.46662606e-18],
#        [1.00000000e+00, 7.09871231e-13],
#        [7.98412730e-10, 9.99999999e-01],
#        [1.00000000e+00, 5.94558250e-21],
#        [1.65991318e-03, 9.98340087e-01],
#        [1.00000000e+00, 2.37072205e-23],
#        [4.16966995e-10, 1.00000000e+00],
#        [1.00000000e+00, 3.27838637e-11],
#        [9.99937726e-01, 6.22744954e-05],
#        [1.00000000e+00, 2.95695617e-16],
#        [1.24868922e-06, 9.99998751e-01],
#        [1.00000000e+00, 5.49743187e-27],
#        [2.03655647e-08, 9.99999980e-01],
#        [1.00000000e+00, 3.42218646e-15],
#        [6.38946237e-10, 9.99999999e-01],
#        [1.00000000e+00, 1.18480910e-17],
#        [1.24015671e-09, 9.99999999e-01],
#        [1.00000000e+00, 1.83839490e-19],
#        [1.00000000e+00, 1.16219272e-13],
#        [1.00000000e+00, 2.93707540e-15],
#        [1.00000000e+00, 1.12573835e-14],
#        [1.00000000e+00, 5.12120854e-17],
#        [1.00000000e+00, 2.26760233e-11],
#        [1.00000000e+00, 4.97540545e-21],
#        [1.00000000e+00, 2.19117467e-13],
#        [2.40518394e-06, 9.99997595e-01],
#        [1.00000000e+00, 3.29011382e-17],
#        [3.08461601e-08, 9.99999969e-01],
#        [1.00000000e+00, 2.33843483e-21],
#        [4.09641860e-09, 9.99999996e-01],
#        [3.00122901e-09, 9.99999997e-01],
#        [1.00000000e+00, 4.55469139e-17],
#        [1.00000000e+00, 3.16917474e-13],
#        [4.71248367e-05, 9.99952875e-01],
#        [1.00000000e+00, 4.95091817e-15],
#        [5.14424910e-08, 9.99999949e-01],
#        [1.00000000e+00, 8.46192023e-28],
#        [2.00152720e-01, 7.99847280e-01],
#        [1.00000000e+00, 1.96814613e-22],
#        [1.00000000e+00, 2.35072064e-12],
#        [1.17300376e-07, 9.99999883e-01],
#        [1.00000000e+00, 5.62705188e-19],
#        [1.37506269e-05, 9.99986249e-01],
#        [1.00000000e+00, 1.75154567e-17],
#        [1.32948467e-07, 9.99999867e-01],
#        [1.00000000e+00, 2.92252660e-20],
#        [9.99999943e-01, 5.70855237e-08],
#        [1.00000000e+00, 2.19038137e-19],
#        [1.00000000e+00, 4.11079460e-17],
#        [1.00000000e+00, 7.58053670e-12],
#        [1.00000000e+00, 1.55778950e-11],
#        [1.00000000e+00, 2.92252660e-20],
#        [3.10857881e-08, 9.99999969e-01],
#        [1.00000000e+00, 2.19134954e-17],
#        [1.00000000e+00, 4.86531665e-24],
#        [1.00000000e+00, 1.43382998e-21],
#        [1.65215051e-08, 9.99999983e-01],
#        [1.00000000e+00, 1.36717018e-17],
#        [1.04953517e-10, 1.00000000e+00],
#        [3.04349246e-06, 9.99996957e-01],
#        [1.00000000e+00, 2.53547415e-23],
#        [1.00000000e+00, 1.40266751e-15],
#        [2.51376471e-09, 9.99999997e-01],
#        [1.00000000e+00, 6.57207393e-21],
#        [7.23715099e-11, 1.00000000e+00],
#        [1.00000000e+00, 4.40781523e-19]])
